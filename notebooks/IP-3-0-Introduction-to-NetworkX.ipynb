# %% [markdown]
# Introduction
# ============
# **Topic**: Introduction to NetworkX
#
# This notebook is a part of a collection of notebooks and includes basic information and examples to implement graphs using NetworkX and apply them in path planning algorithms.
#
# Version | Author
# ------------ | -------------
# 0.2 | Björn Hein
#
# License is based on Creative Commons: Attribution-NonCommercial 4.0 International (CC BY-NC 4.0) (pls. check: http://creativecommons.org/licenses/by-nc/4.0/)
#
# Content:
#
# * [Graph handling](#Graph-handling)
# * [Drawing graphs](#Drawing-graphs)
# * [Lecture examples](#Lecture-examples)
# * [Planning-related graph examples](#Planning-related-graph-examples)
# * [Exercise](#Exercise)

# %%
import networkx as nx

# %%
print(nx.__version__)
# Out:
# 3.5

# %% [markdown]
# # Graph handling
# ## Creating a graph

# %%
G = nx.Graph()

# %% [markdown]
# ## Adding Nodes

# %%
G.add_node(1) # G.add_node(id) --> id can be any hashable object

# %%
G.add_nodes_from([2,3,"A"])

# %%
print(G)
# Out:
# Graph with 4 nodes and 0 edges

# %% [markdown]
# ## Adding Edges

# %%
G.add_edge(1,2)
e=(2,3)
G.add_edge(*e)
G.add_node("Bob")
G.add_node("Marie")
G.add_edge("Bob","Marie")
G.add_edge("Bob","A")

# %%
G.number_of_nodes()
# Out:
# 6

# %%
G.nodes()
# Out:
# NodeView((1, 2, 3, 'A', 'Bob', 'Marie'))

# %%
# show all elements of the nodes - currently empty
G.nodes(data=True)
# Out:
# NodeDataView({1: {}, 2: {}, 3: {}, 'A': {}, 'Bob': {}, 'Marie': {}})

# %%
G.edges(data=True)
# Out:
# EdgeDataView([(1, 2, {}), (2, 3, {}), ('A', 'Bob', {}), ('Bob', 'Marie', {})])

# %% [markdown]
# ## Node attributes

# %%
G.nodes[1]['color']="red"
G.nodes[1]['time']=4.3
G.nodes["A"]['Amazing']="Parameter"

# %%
G.nodes[1]
# Out:
# {'color': 'red', 'time': 4.3}

# %%
G.nodes['A']
# Out:
# {'Amazing': 'Parameter'}

# %%
G.nodes(data=True)
# Out:
# NodeDataView({1: {'color': 'red', 'time': 4.3}, 2: {}, 3: {}, 'A': {'Amazing': 'Parameter'}, 'Bob': {}, 'Marie': {}})

# %% [markdown]
# ## Edge attributes

# %%
G["Bob"]["Marie"]["weight"]=100.3

# %%
G["Bob"]["Marie"]
# Out:
# {'weight': 100.3}

# %% [markdown]
# ## Analyzing

# %%
con_comp = nx.connected_components(G)

# %%
for a in list(con_comp):
    print(a)
# Out:
# {1, 2, 3}
# {'A', 'Bob', 'Marie'}

# %%
G.add_edge("A",1)
G.add_edge(1,'1')

# %%
con_comp = nx.connected_components(G)

# %%
for a in list(con_comp):
    print(a)
# Out:
# {'1', 1, 2, 3, 'A', 'Bob', 'Marie'}

# %% [markdown]
# # Drawing graphs

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots()
nx.draw(G, ax=axes, with_labels=True)

# %% [markdown]
# # Lecture examples
# Following examples are according to the slides provided in the lecture.

# %% [markdown]
# ## Initialiizing graphs
# ### Undirected graph

# %%
G_undir = nx.Graph()

# %%
G_undir.add_nodes_from(["A","B","C","D"])

# %%
G_undir.add_edges_from([("A","B"),("B","C"),("C","D"),("D","B")])

# %%
colors = ['lightblue' for i in range(4)]
print(colors)
# Out:
# ['lightblue', 'lightblue', 'lightblue', 'lightblue']

# %%
#colors_two = {"A": "lightblue", "B": "red"}

# %%
colors[0]="Yellow"

# %%
fig, axes = plt.subplots()
nx.draw(G_undir,with_labels=True, node_color=colors, node_size=600.0, ax=axes) 
# when using dict type colors_two, then you need to give set `node_color=colors_two.values()`
# Remark: ax=axes can be omitted if you just want to draw in the last generated figure (e.g. by plt.subplots() or plt.figure(), etc)
# It gives you the possibility to draw in a specified figure, even when plotted in the notebook before.

# %% [markdown]
# ### Directed graph

# %%
G_dir = nx.DiGraph()

# %%
G_dir.add_nodes_from(["A","B","C","D"])

# %%
G_dir.add_edges_from([("A","B"),("B","C"),("C","D"),("D","B")])

# %%
fig, axes = plt.subplots()
nx.draw(G_dir,with_labels=True, node_color=colors, node_size=600.0)

# %% [markdown]
# ## Add attribute to edges

# %% [markdown]
# ### Undirected graph

# %%
#fig, axes = plt.subplots()

# Set weight to edges
G_undir["A"]["B"]["weight"] = 3
G_undir["B"]["C"]["weight"] = 2
G_undir["C"]["D"]["weight"] = 4
G_undir["D"]["B"]["weight"] = 10

# Generate positions based on specific layout "spring"
pos = nx.spiral_layout(G_undir)

# %%
print(pos)
# Out:
# {'A': array([-0.64153279, -0.68555087]), 'B': array([-0.03307913, -0.46344795]), 'C': array([0.34927952, 0.14899882]), 'D': array([0.32533239, 1.        ])}

# %%
print(pos)
# Draw nodes and edges
nx.draw(G_undir, pos,  with_labels=True, node_color=colors, node_size=600.0)

# Get specific edge attribute and draw
edge_attributes = nx.get_edge_attributes(G_undir,'weight')
nx.draw_networkx_edge_labels(G_undir, pos, edge_labels=edge_attributes)
# Out:
# {'A': array([-0.64153279, -0.68555087]), 'B': array([-0.03307913, -0.46344795]), 'C': array([0.34927952, 0.14899882]), 'D': array([0.32533239, 1.        ])}
# {('A', 'B'): Text(-0.33730071961614233, -0.5744974993643721, '3'),
#  ('B', 'C'): Text(0.15809884804119412, -0.15722672307986774, '2'),
#  ('B', 'D'): Text(0.14612763196022793, 0.2682801106031316, '10'),
#  ('C', 'D'): Text(0.3373056745343288, 0.5745095328596701, '4')}

# %% [markdown]
# ### Directed Graph

# %%
fig, axes = plt.subplots()

# Set weight to edges
G_dir["A"]["B"]["weight"] = 2
G_dir["B"]["C"]["weight"] = 3
G_dir["C"]["D"]["weight"] = 8
G_dir["D"]["B"]["weight"] = 7

G_dir.add_edge("B","D", weight=4)
# or 
# G_dir.add_edge("B","D", weight=4)
# G_dir["B"]["D"]["weight"] = 4

# Draw nodes and edges
nx.draw(G_dir, pos, with_labels=True, node_color=colors, node_size=600.0)

# Get specific edge attribute and draw
edge_attributes = nx.get_edge_attributes(G_dir,'weight')
nx.draw_networkx_edge_labels(G_dir, pos, edge_labels=edge_attributes)
# Out:
# {('A', 'B'): Text(-0.33730444158878203, -0.5744988579904428, '2'),
#  ('B', 'C'): Text(0.15809963128149018, -0.1572254685169443, '3'),
#  ('B', 'D'): Text(0.14612330264773488, 0.26826243337169364, '4'),
#  ('C', 'D'): Text(0.33730557995777755, 0.5745128937950281, '8'),
#  ('D', 'B'): Text(0.14612995980657373, 0.26828961554847197, '7')}

# %%
fig, axes = plt.subplots()

# shift labels so they don't overlap, e.g. edge ("B","D") and ("D","B")
nx.draw(G_dir, pos, with_labels=True, node_color=colors, node_size=600.0)
nx.draw_networkx_edge_labels(G_dir, pos, edge_labels=edge_attributes,  label_pos=0.3)
# Out:
# {('A', 'B'): Text(-0.4507253555574123, -0.615900723498703, '2'),
#  ('B', 'C'): Text(0.08848229701656862, -0.26873572510122257, '3'),
#  ('B', 'D'): Text(0.07852652269979465, -0.007745345136297432, '4'),
#  ('C', 'D'): Text(0.34155815970619186, 0.4233903855179464, '8'),
#  ('D', 'B'): Text(0.21372673975451373, 0.5442973940564628, '7')}

# %% [markdown]
# ## Finding paths
# http://networkx.github.io/documentation/latest/reference/algorithms.shortest_paths.html

# %% [markdown]
# ### Undirected Graph

# %%
shortest_path = nx.shortest_path(G_undir,source="A",target="D", weight="weight")

# %%
print(shortest_path)
# Out:
# ['A', 'B', 'C', 'D']

# %%
fig, axes = plt.subplots()

# Draw nodes and edges
nx.draw(G_undir, pos, with_labels=True, node_color=colors, node_size=600.0)

# Generate and draw the solution path
edgeList = [(shortest_path[i],shortest_path[i+1]) for i in range(len(shortest_path)-1)]
print(pos)
print(shortest_path)
print(edgeList)
nx.draw_networkx_edges(G_undir, pos, edgelist=edgeList, edge_color="red", width=4.0)

# Get specific edge attribute and draw
edge_attributes = nx.get_edge_attributes(G_undir,'weight')
print(edge_attributes)
nx.draw_networkx_edge_labels(G_undir, pos, edge_labels=edge_attributes)
# Out:
# {'A': array([-0.64153279, -0.68555087]), 'B': array([-0.03307913, -0.46344795]), 'C': array([0.34927952, 0.14899882]), 'D': array([0.32533239, 1.        ])}
# ['A', 'B', 'C', 'D']
# [('A', 'B'), ('B', 'C'), ('C', 'D')]
# {('A', 'B'): 3, ('B', 'C'): 2, ('B', 'D'): 10, ('C', 'D'): 4}
# {('A', 'B'): Text(-0.33730444158878203, -0.5744988579904428, '3'),
#  ('B', 'C'): Text(0.15809963128149018, -0.1572254685169443, '2'),
#  ('B', 'D'): Text(0.14612330264773488, 0.26826243337169364, '10'),
#  ('C', 'D'): Text(0.33730557995777755, 0.5745128937950281, '4')}

# %%
costs_undir = sum(edge_attributes[i] for i in edgeList)
print(costs_undir)
# Out:
# 9

# %% [markdown]
# ### Directed Graph

# %%
# remove edge B-D from example
try:
    G_dir.remove_edge("B","D")
except:
    print("no edge existing")

# %%
shortest_path = nx.shortest_path(G_dir,source="A",target="D", weight="weight")
print(shortest_path)
# Out:
# ['A', 'B', 'C', 'D']

# %%
fig, axes = plt.subplots()

# Draw nodes and edges
nx.draw(G_dir, pos, with_labels=True, node_color=colors, node_size=600.0)

# Get specific edge attribute and draw
edge_attributes = nx.get_edge_attributes(G_dir,'weight')
nx.draw_networkx_edge_labels(G_dir, pos, edge_labels=edge_attributes)

# Generate and draw the solution path
edgeList = [(shortest_path[i],shortest_path[i+1]) for i in range(len(shortest_path)-1)]
nx.draw_networkx_edges(G_dir, pos, edgelist=edgeList, edge_color="red", width=4.0)
# Out:
# [<matplotlib.patches.FancyArrowPatch at 0x7fff7d8f76e0>,
#  <matplotlib.patches.FancyArrowPatch at 0x7fff7d8c70e0>,
#  <matplotlib.patches.FancyArrowPatch at 0x7fff7d945940>]

# %%
costs_dir = sum(edge_attributes[i] for i in edgeList)
print(costs_dir)
# Out:
# 13

# %% [markdown]
# ## Further tests

# %%
nx.is_connected(G_undir)
# Out:
# True

# %%
nx.cycle_basis(G_undir)
# Out:
# [['C', 'B', 'D']]

# %%
for i in nx.simple_cycles(G_dir):
    print(i)
# Out:
# ['C', 'D', 'B']

# %% [markdown]
# ## Representation

# %%
print(G.nodes())
# Out:
# [1, 2, 3, 'A', 'Bob', 'Marie', '1']

# %% [markdown]
# Add again edge with weight=4.0 between B-D to align with example in slides

# %%
G_dir.add_edge("B","D", weight=4)

# %% [markdown]
# Check https://networkx.github.io/documentation/latest/reference/generated/networkx.linalg.graphmatrix.adjacency_matrix.html#networkx.linalg.graphmatrix.adjacency_matrix !

# %%
print(G_dir.nodes())
print(sorted(G_dir.nodes()))
# Out:
# ['A', 'B', 'C', 'D']
# ['A', 'B', 'C', 'D']

# %%
adj_matrix = nx.adjacency_matrix(G_dir, sorted(G_dir.nodes()))

# %%
adj_matrix.toarray()
# Out:
# array([[0, 2, 0, 0],
#        [0, 0, 3, 4],
#        [0, 0, 0, 8],
#        [0, 7, 0, 0]])

# %% [markdown]
# # Layouting
#
# In the planning environment it will be important to place the node at certain positions. In the following some hints are given how to use attributes of nodes in NetworkX to do so.

# %%
G_graph = nx.Graph()

# %%
# Attribute "mypos" and not "pos" is chosen to demonstrate, that there is no dedicate position attribute
G_graph.add_node("A", mypos = [0,1])

# %%
G_graph.add_node("B", mypos = [10,1])
G_graph.add_node("C", mypos = [1,10])
G_graph.add_node("D", mypos = [1,8])

# %%
G_graph.add_edge("A","B")
G_graph.add_edge("B","C")

# %%
G_graph.nodes(data=True)
# Out:
# NodeDataView({'A': {'mypos': [0, 1]}, 'B': {'mypos': [10, 1]}, 'C': {'mypos': [1, 10]}, 'D': {'mypos': [1, 8]}})

# %%
pos_dict = nx.get_node_attributes(G_graph,'mypos')

# %%
pos_dict
# Out:
# {'A': [0, 1], 'B': [10, 1], 'C': [1, 10], 'D': [1, 8]}

# %%
fig, axes = plt.subplots()

nx.draw(G_graph, pos=pos_dict, with_labels=True)

# %%
fig, axes = plt.subplots()

nx.draw(G_graph, pos=pos_dict, with_labels=False)
nx.draw_networkx_edges(G_graph,pos_dict,
                           edge_color='b',
                            width=3.0
                        )

# %%
for node in G_graph.nodes(data=True):
    print(node)
# Out:
# ('A', {'mypos': [0, 1]})
# ('B', {'mypos': [10, 1]})
# ('C', {'mypos': [1, 10]})
# ('D', {'mypos': [1, 8]})

# %%
a = G_graph.nodes["A"]

# %% [markdown]
# # Planning-related graph examples
#
# The examples above show the basic NetworkX API. For path planning, the graph usually represents a roadmap: nodes store configurations or positions and edges store feasible local connections. Edge weights often represent geometric distance or traversal cost.

# %% [markdown]
# ## Weighted and unweighted shortest paths
#
# Without a `weight` parameter, NetworkX minimizes the number of edges. With `weight="weight"`, it minimizes the sum of edge weights.

# %%
G_cost = nx.Graph()
G_cost.add_edge("start", "A", weight=1)
G_cost.add_edge("A", "goal", weight=10)
G_cost.add_edge("start", "B", weight=3)
G_cost.add_edge("B", "C", weight=3)
G_cost.add_edge("C", "goal", weight=3)

print("Unweighted shortest path:", nx.shortest_path(G_cost, "start", "goal"))
print("Weighted shortest path:", nx.shortest_path(G_cost, "start", "goal", weight="weight"))
print("Weighted path length:", nx.shortest_path_length(G_cost, "start", "goal", weight="weight"))
# Out:
# Unweighted shortest path: ['start', 'A', 'goal']
# Weighted shortest path: ['start', 'B', 'C', 'goal']
# Weighted path length: 9

# %%
pos_cost = {
    "start": (0, 0),
    "A": (1, 1),
    "goal": (4, 0),
    "B": (1, -1),
    "C": (3, -1),
}
weighted_path = nx.shortest_path(G_cost, "start", "goal", weight="weight")
path_edges = list(zip(weighted_path[:-1], weighted_path[1:]))

fig, axes = plt.subplots()
nx.draw(G_cost, pos_cost, with_labels=True, node_color="lightblue", node_size=900, ax=axes)
nx.draw_networkx_edge_labels(
    G_cost,
    pos_cost,
    edge_labels=nx.get_edge_attributes(G_cost, "weight"),
    ax=axes,
)
nx.draw_networkx_edges(G_cost, pos_cost, edgelist=path_edges, edge_color="red", width=4, ax=axes)

# %% [markdown]
# ## Geometric roadmap graph
#
# In a roadmap graph, every node can store a position. Edges are added when two nodes are close enough. The edge weight is the Euclidean distance between the positions.

# %%
import math
import random

random.seed(7)

num_nodes = 25
connection_radius = 0.32
G_roadmap = nx.Graph()

for node_id in range(num_nodes):
    position = (random.random(), random.random())
    G_roadmap.add_node(node_id, pos=position)

for node_a in G_roadmap.nodes:
    for node_b in G_roadmap.nodes:
        if node_a >= node_b:
            continue
        distance = math.dist(G_roadmap.nodes[node_a]["pos"], G_roadmap.nodes[node_b]["pos"])
        if distance <= connection_radius:
            G_roadmap.add_edge(node_a, node_b, weight=distance)

print(G_roadmap)
print("Connected:", nx.is_connected(G_roadmap))
print("Number of connected components:", nx.number_connected_components(G_roadmap))
# Out:
# Graph with 25 nodes and 70 edges
# Connected: True
# Number of connected components: 1

# %%
pos_roadmap = nx.get_node_attributes(G_roadmap, "pos")

fig, axes = plt.subplots(figsize=(6, 6))
nx.draw(
    G_roadmap,
    pos_roadmap,
    with_labels=True,
    node_color="lightblue",
    node_size=350,
    edge_color="0.75",
    ax=axes,
)
axes.set_aspect("equal")

# %% [markdown]
# ## Dijkstra and A* on the roadmap
#
# Dijkstra uses the edge weights only. A* additionally uses a heuristic. For geometric graphs, the straight-line distance to the goal is a natural admissible heuristic.

# %%
start_node = 0
goal_node = num_nodes - 1

def euclidean_heuristic(node_a, node_b):
    pos_a = G_roadmap.nodes[node_a]["pos"]
    pos_b = G_roadmap.nodes[node_b]["pos"]
    return math.dist(pos_a, pos_b)

if nx.has_path(G_roadmap, start_node, goal_node):
    dijkstra_path = nx.dijkstra_path(G_roadmap, start_node, goal_node, weight="weight")
    astar_path = nx.astar_path(
        G_roadmap,
        start_node,
        goal_node,
        heuristic=euclidean_heuristic,
        weight="weight",
    )
    print("Dijkstra:", dijkstra_path)
    print("A*:", astar_path)
    print("Path length:", nx.path_weight(G_roadmap, astar_path, weight="weight"))
else:
    print("No path found. Increase connection_radius or choose nodes in the same component.")
# Out:
# Dijkstra: [0, 20, 24]
# A*: [0, 20, 24]
# Path length: 0.4737660703084297

# %%
fig, axes = plt.subplots(figsize=(6, 6))
nx.draw(
    G_roadmap,
    pos_roadmap,
    with_labels=True,
    node_color="lightblue",
    node_size=350,
    edge_color="0.75",
    ax=axes,
)

if nx.has_path(G_roadmap, start_node, goal_node):
    solution_edges = list(zip(astar_path[:-1], astar_path[1:]))
    nx.draw_networkx_edges(G_roadmap, pos_roadmap, edgelist=solution_edges, edge_color="red", width=4, ax=axes)
    nx.draw_networkx_nodes(
        G_roadmap,
        pos_roadmap,
        nodelist=[start_node],
        node_color="green",
        node_size=600,
        ax=axes,
    )
    nx.draw_networkx_nodes(
        G_roadmap,
        pos_roadmap,
        nodelist=[goal_node],
        node_color="orange",
        node_size=600,
        ax=axes,
    )
axes.set_aspect("equal")

# %% [markdown]
# ## Handling disconnected graphs
#
# Roadmaps are not always connected. Before searching a path, check whether start and goal lie in the same connected component. This avoids exceptions and makes planner failures easier to diagnose.

# %%
components = list(nx.connected_components(G_roadmap))
largest_component = max(components, key=len)

print("Component sizes:", sorted([len(component) for component in components], reverse=True))
print("Start and goal in same component:", any(start_node in component and goal_node in component for component in components))

try:
    path = nx.shortest_path(G_roadmap, start_node, goal_node, weight="weight")
    print("Shortest path:", path)
except nx.NetworkXNoPath:
    print("NetworkXNoPath: start and goal are not connected.")
# Out:
# Component sizes: [25]
# Start and goal in same component: True
# Shortest path: [0, 20, 24]

# %% [markdown]
# ## Roadmap quality indicators
#
# Simple graph metrics help to assess whether a sampled roadmap is likely to be useful for planning.

# %%
average_degree = sum(dict(G_roadmap.degree()).values()) / G_roadmap.number_of_nodes()
print("Nodes:", G_roadmap.number_of_nodes())
print("Edges:", G_roadmap.number_of_edges())
print("Average degree:", average_degree)
print("Density:", nx.density(G_roadmap))
print("Largest component size:", len(largest_component))
# Out:
# Nodes: 25
# Edges: 70
# Average degree: 5.6
# Density: 0.23333333333333334
# Largest component size: 25

# %% [markdown]
# Conclusion
# ==========

# %% [markdown]
# Using and drawing of graphs can be done very nicely with the combination of networkX and matplotlib

# %% [markdown]
# # Exercise

# %% [markdown]
# 1. Create a graph with `x` nodes at random positions.
# 2. Create a graph with `x` nodes at random positions and connect all nodes with edges.
# 3. Create a graph with `x` nodes at random positions and connect nodes whose distance is below a given threshold.
# 4. Store the Euclidean distance as edge weight.
# 5. Choose start and goal nodes and find the weighted shortest path.
# 6. Draw the graph, mark start and goal, and highlight the solution path.
# 7. Change the distance threshold and observe how connectivity, average degree, and path length change.

# %%
random.seed(7)

num_nodes = 5
connection_radius = 0.32
graph_xnodes = nx.Graph()

for node_id in range(num_nodes):
    position = (random.random(), random.random())
    graph_xnodes.add_node(node_id, pos=position)

print(graph_xnodes.nodes.data)

for a_node in graph_xnodes.nodes:
    for b_node in graph_xnodes.nodes:
        skip = False
        #for edge in graph_xnodes.edges:
        #    if edge[0] == a_node or edge[1] == a_node:
        #        print("a passed")
        #        skip = True
        #    if edge[0] == b_node or edge[1] == b_node:
        #        print("b passed")
        #        skip = True
        if not skip and a_node != b_node:
            graph_xnodes.add_edge(a_node, b_node, weight=1.0)

print(graph_xnodes.edges.data)

pos_roadmap = nx.get_node_attributes(graph_xnodes, "pos")

fig, axes = plt.subplots(figsize=(6, 6))
nx.draw(
    graph_xnodes,
    pos_roadmap,
    with_labels=True,
    node_color="lightblue",
    node_size=350,
    edge_color="0.75",
    ax=axes,
)
axes.set_aspect("equal")
# Out:
# <bound method NodeView.data of NodeView((0, 1, 2, 3, 4))>
# <bound method OutEdgeView.data of EdgeView([(0, 1), (0, 2), (0, 3), (0, 4), (1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4)])>
